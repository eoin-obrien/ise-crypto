# %% [markdown]
# # ISE Cryptography Week 1
#
# These challenges are going to be much easier if you complete the exercises from the lecture first!
# You should have working implementations of the Caesar cipher and One-Time Pad, and be comfortable working with bytes in Python before you start.

# %% [markdown]
# ## Challenge 1: Caesar Cipher I
#
# Attack the following ciphertext, encrypted using a Caesar cipher. Figure out the plaintext and the shift used to encrypt it.
#
# ```
# Ykbxgwl, Khftgl, vhngmkrfxg, exgw fx rhnk xtkl;
# B vhfx mh unkr Vtxltk, ghm mh iktblx abf.
# Max xobe matm fxg wh eboxl tymxk maxf;
# Max zhhw bl hym bgmxkkxw pbma maxbk uhgxl;
# Lh exm bm ux pbma Vtxltk.
# ```

# %% [markdown]
# ## Challenge 2: Caesar Cipher II
#
# This time around, whitespace and punctuation have been removed from the plaintext before encryption. Decrypt the following ciphertext and figure out the shift used to encrypt it.
#
# ```
# xkazxbpxoppmfofqoxkdfkdcloobsbkdbtfqexqbyvefppfabzljbelqcoljebiipexiifkqebpbzlkcfkbptfqexjlkxozepslfzbzovexslzxkaibqpifmqebaldplctxo
# ```

# %% [markdown]
# ## Challenge 3: Substitution Cipher I
#
# Let's try something a bit more difficult. This message has been encrypted using a substitution cipher, but this time, there's no guarantee that the ciphertext alphabet is shifted in order. Any letter could be substituted for any other letter, so brute force isn't quite so viable here. Decrypt the following ciphertext and figure out the mapping!
#
# ```
# gsv tildgs lu xibkgltizksrx gvxsmloltb szh izrhvw z mfnyvi lu ovtzo rhhfvh rm gsv rmulinzgrlm ztv.
# xibkgltizksb'h klgvmgrzo uli fhv zh z gllo uli vhkrlmztv zmw hvwrgrlm szh ovw nzmb tlevimnvmgh gl xozhhrub rg zh z dvzklm zmw gl ornrg li vevm kilsryrg rgh fhv zmw vcklig.
# rm hlnv qfirhwrxgrlmh dsviv gsv fhv lu xibkgltizksb rh ovtzo, ozdh kvinrg rmevhgrtzglih gl xlnkvo gsv wrhxolhfiv lu vmxibkgrlm pvbh uli wlxfnvmgh ivovezmg gl zm rmevhgrtzgrlm.
# xibkgltizksb zohl kozbh z nzqli ilov rm wrtrgzo irtsgh nzmztvnvmg zmw xlkbirtsg rmuirmtvnvmg wrhkfgvh drgs ivtziw gl wrtrgzo nvwrz.
# ```

# %% [markdown]
# ## Challenge 4: Substitution Cipher II
#
# Another substitution cipher! But this time, no punctuation or whitespace. You know the drill - see if you can crack the code and figure out the plaintext and mapping. Hint: frequency analysis is your friend.
#
# ```
# ...
# ```

# %% [markdown]
# ## Challenge 5: One-Time Pad (gone right)
#
# Let's shake things up a bit! I've encrypted some text with a one-time pad. This is a perfectly secure encryption scheme, as long as the key is truly random, at least as long as the message, and never reused.
#
# Instead of asking you to decrypt the message, your task this time is a little different! Given the following cyphertext, create a plaintext message of the same length and then figure out the key that encrypts your plaintext to the given cyphertext.
#
# You can do this with __any__ plaintext of the same length. This should give you an intuitive understanding for why the one-time pad is perfectly secure!
#
# **Hint:** write a Python script to help you out! Don't attempt to do this by hand.
#
# **Hint:** don't want to match the length precisely? You can pad your plaintext with spaces or null bytes, or truncate it to match the length of the ciphertext.
#
# ```python
# ciphertext = b'\xb2;\x85\x11\xd5>\xd7H2\x8d.\x94\xe3O\xb6\x8di~<0L\x1e\x90\x9145\x98\x88|\xccB\x0f\xec\xc9\xec>\xec\x9bJ\xcd8\xdej\x10\xc5K\xa9o\xc7\x85=\x84(\x17\xe2,\x1c\xe1PT\x11\xdd_\x9e\xd7\xda\x82\xf1F\xfa\x93P\x9b.dI\x8f\x9d\xcb`,\xeb\xa29]b\xdb\\\x80\xd1\xb7$\xa1xN\x7f\xe5\xb7\n\xbc\xf6O\xe9\x0e'
# ```

# %% [markdown]
# ## Challenge 6: One-Time Pad (gone wrong)
#
# This time, the messages have been encrypted using a one-time pad. Luckily for you, the key was reused to encrypt three different messages! See if you can exploit this fatal mistake and recover the key and plaintexts.
#
# This is the toughest challenge by far, so don't worry if you can't crack it! Remember, brute force and frequency analysis aren't viable options here. Think back to what we discussed in class and try to automate your attack as much as possible. It would take way too long to attempt this by hand!
#
# **Hint:** the messages have all been padded to the same length by adding null bytes (`\x00`) to the end of the plaintext if needed.
#
# **Hint:** all of the messages are in English.
#
#
# ```python
# messages = [
#     b'\xd3\xc4~\xa1N\x10\x9d2\xe6\xba\x99\xfd;w\x99-\xb0E\xcc\x8a\x82v\xe3h,\xc8Gh\xe6\x10\xd2\xf6\xa2\x08)F\r\xe7\xc9-\x03\xef\xd4XQ\xf6\xbe\xff\xe0\x8f\xadF>\xacM\xbd\xc4\xa4d#&P\xed\xacrp\xb3B\x1eX\xb3\xa0\xbdE\xc5\xe4\x1a\xdf{\xf7\xac\x08\xf5\xfd\xf0u\xbb\xac;t\xe9\xe8\x81\xbfZ\xcb\xdcr%\xe8\x8e1/\xe9\x0b.R\x9a)\t"\xdcD1N\x85C\xcd\x00\xf8\xde&\xbfI\t\x0c\x83\x88\xc1J|\xf9hP\xd9\x82\xdc\xffv\\\x98\xabTr\x9e\x8f\x10\xd8OM\x88,\x1b\x88.\x07\x05\xcb\xeb\xd8\x02x]\xb5\x8czL\x07\xdc\xc2\xcaS\xb8\xcb\xfd\xaax\x04~r\xd4\xc3-\xbd\x1e\xbe\xcb\xcd\xdaxq\x96 \x7f\xfb\x84\xf5\x08Z-h\xa8n\x88V\x97\xa1\xa8\x91K\xd6\x1d4\xf2\xf1w \xe3#TY\xf6\xcav\xbd\xb5\xf0\xec\xe4/\x92\x8df\xa4\x0c7;\x8b\xc5\x1f\xefD\xe7\x19\x9d1\xcfiK\x92\xb1q\xe8>-[\xa3\xbf\x98\xbf\xbd\x06u\xfeY\x18XY\xde\xd4$\x8b\x8du\x84\xbc\x16\xe78M\x17_\x01\xcc\x85>$p\xdb\xb7\xe3\x9e\xc